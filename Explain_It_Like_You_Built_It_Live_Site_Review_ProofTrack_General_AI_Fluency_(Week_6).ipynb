# %% [markdown]
# <a href="https://colab.research.google.com/github/Zekeriya-Ui/main/blob/main/Explain_It_Like_You_Built_It_Live_Site_Review_ProofTrack_General_AI_Fluency_(Week_6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Resources
#
# ### Explain It Like You Built It / Live Site Review ProofTrack: General AI Fluency (Week 6)
#
# **Live Site URL:** Zacharia Maganga Nyambu Portfolio https://kapitals-pi.blogspot.com/p/zacharia-maganga-nyambu-portfolio.html
#
# 1.  **Reviewer Feedback Summary**
#
# | Priority Level | Item / Observation                                            | Status on Live Site |
# | :------------- | :------------------------------------------------------------ | :------------------ |
# | Must-Fix       | Navigation & Anchor Links: Smooth jump/scroll navigation to portfolio sections without leaving the page. | Addressed / Live    |
# | Must-Fix       | Mobile Responsiveness: Layout readability across viewports (cards adjusting flexibly on smaller screens). | Addressed / Live    |
# | Nice-to-Have   | Blogger Template Styling Isolation: Custom CSS resets to prevent default Blogger skin margins from breaking modern card alignments. | Integrated          |
# | Nice-to-Have   | Direct Link Affordances: External repository and project links opening safely in new tabs (target="_blank"). | Integrated          |
#
# 2.  **Evidence of Must-Fixes Addressed on Live Site**
#
# **Fix 1: Section Anchoring & Navigation**
#
# The Issue: Headers or top navigation on custom Blogger pages can lose anchor context due to dynamic layout URLs.
#
# Live Implementation: Verified that inline section anchors (e.g., #projects, #about) connect cleanly across the page structure on kapitals-pi.blogspot.com, keeping the user in context without triggering full page reloads.
#
# **Fix 2: Responsive Container & Layout Adjustment**
#
# The Issue: Dense technical project summaries (ML workflows, data visualizations) often overflow horizontal containers on mobile viewports inside blog templates.
#
# Live Implementation: Styled project cards and layout wrappers using fluid widths (max-width: 100%) and CSS Flexbox properties, ensuring text wraps cleanly and visual elements stack vertically on smaller mobile displays.
#
# 3.  **Plain-Language Explanation of the Build Mechanism**
#
# **My Build Piece:** Integrating modern custom HTML/CSS cards inside a Blogger page structure.
#
# **Explanation:**
#
# "Blogger templates normally enforce rigid, traditional blog post styling (dates, sidebars, wide margins). To turn a static Blogspot page into a clean, modern engineer portfolio, I wrote self-contained HTML/CSS blocks using Flexbox layouts inside the page editor.
#
# Instead of letting the default blog layout dictate how my projects appear, my inline CSS resets standard margins and forces the cards into responsive flex containers. When viewed on desktop, elements sit neatly side-by-side; when viewed on mobile, the container automatically stacks the project cards vertically so nothing gets cut off or forces horizontal scrolling."
