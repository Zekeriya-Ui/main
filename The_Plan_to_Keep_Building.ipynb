# %% [markdown]
# <a href="https://colab.research.google.com/github/Zekeriya-Ui/main/blob/main/The_Plan_to_Keep_Building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Resources
#
# ### Assignment Submission: The Plan to Keep Building
# Track: General AI Fluency
#
# Week: 9
#
# 1. "How to Add the Next Case" Workflow
# To add a new case study without friction, I will follow this repeatable 3-step process:
#
# Location: Publish directly to my portfolio page at [insert URL/path, e.g., [yourname.com/portfolio](https://yourname.com/portfolio) or GitHub README].
#
# Three-Beat Content Structure:
#
# Beat 1 (The Problem): Define the core obstacle, context, and why it mattered in 2–3 sentences.
#
# Beat 2 (What I Did): Outline the AI workflow, prompts, stack, and artifacts built to address it.
#
# Beat 3 (What Came of It): Highlight key metrics, concrete outputs, or quantifiable efficiency gains.
#
# Publish Checklist: Format using standard markdown, embed relevant visual assets/diagrams, and link from the main index.
#
# 2. Next Case Study & Concrete Reminder
# Named Piece of Work: [Insert specific project name, e.g., "AI-Powered Customer Support Triage System Case Study"]
#
# Target Completion Date: [Insert Date, e.g., October 15, 2026]
#
# Reminder Setup: Set a recurring calendar nudge for every [e.g., alternate Friday at 3:00 PM] in Google Calendar titled "Portfolio Update: Draft Next Beat".
# (Evidence: Google Calendar event created with a 15-minute notification lead time).
#
# 3. Build Context Preservation
# Claude Project Status: Active & Preserved.
#
# Stored Context: System prompts, personal voice guidelines, tech stack configuration, and branding identity kit are stored in the Project Knowledge base.
#
# Workflow for Next Update: Open the existing Claude Project, input raw notes from the completed work, and prompt it to draft the 3-beat structure matching established tone and formatting constraints.
