# %% [markdown]
# <a href="https://colab.research.google.com/github/Zekeriya-Ui/main/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My lane will be **"Iris Species Classification for Horticultural Decision Support"**.
#
# This lane focuses on classifying Iris species based on their physical characteristics (sepal and petal dimensions). The ability to accurately classify these species can significantly aid horticulturists, botanists, and gardeners in plant identification, cultivation, and breeding programs. This classic foundational problem allows for clear exploration of classification techniques and their utility in biological applications, making it a valuable learning and development path.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# My work aims to improve the decision-making process for **identifying Iris species**. Horticulturists and botanists typically **act** on this information to ensure correct plant identification for research, conservation, or commercial purposes.
#
# The **cost of a wrong recommendation** could be significant. It might lead to mislabeling of plants, incorrect cultivation practices (as different species may have distinct needs), and potentially flawed scientific research or breeding outcomes. In commercial settings, misidentified plants could result in financial losses due to unsuitable growing conditions or mis-selling to customers.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Loading the starter CSV
#
# To begin, we'll load the provided starter CSV file into a pandas DataFrame. This allows us to quickly inspect its structure and contents, which is crucial for understanding the data we'll be working with. We'll then display the first few rows and a summary of the data types and non-null values to get an initial overview.

# %%
import pandas as pd

# Using the locally uploaded CSV file
dataset_path = '/content/IRIS DATA - Sheet1.csv'

try:
    # The Iris dataset does not have a header, so we explicitly set header=None
    # and provide column names for clarity.
    column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
    df = pd.read_csv(dataset_path, header=None, names=column_names)
    print("Successfully loaded data.")
    print("\nFirst 5 rows of the DataFrame:")
    display(df.head())
    print("\nDataFrame Info:")
    display(df.info())
except Exception as e:
    print(f"An error occurred while loading the CSV. Please ensure the file path is correct and the file is accessible: {e}")
# Out:
# Successfully loaded data.
#
# First 5 rows of the DataFrame:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
# 2-3 real numbers that make your lane look worth the next 7 weeks

# Example: Display some key statistics from the loaded dataset
print(f"Average Sepal Length: {df['sepal_length'].mean():.2f} cm")
print(f"Average Petal Length: {df['petal_length'].mean():.2f} cm")
print(f"Number of unique species: {df['species'].nunique()}")

# You can also show other relevant statistics like min/max, standard deviation,
# or value counts for categorical columns based on your specific research question.
# Out:
# Average Sepal Length: 5.84 cm
# Average Petal Length: 3.76 cm
# Number of unique species: 3

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# Based on the provided Iris dataset and any developed model, my work will be able to provide **observed, directional decision-support** for classifying Iris species based on sepal and petal measurements. It will indicate the most likely species given these physical characteristics, offering a tool to assist in identification. The findings will be specific to the features included in the dataset.
#
# However, this work will **not provide causal proof** that certain measurements *cause* a plant to be a particular species. It will not predict global ecological patterns or provide insights beyond the scope of the given data. The model's performance is limited by the representativeness and quality of the Iris dataset used for training, and its applicability to other Iris varieties or different environmental conditions might require further validation. It also doesn't account for other unmeasured factors like genetic markers.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
